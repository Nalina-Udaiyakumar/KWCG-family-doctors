# %% [markdown]
# # Web scraping using Selenium for doctor search on CPSO website.
# Scraping the name, location, phone numbers and email of the family physicians in the Kitchener Waterloo region

# %% [markdown]
# ## Libraries

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

import time
import os
import pandas as pd
import numpy as np

# Set working directory
os.chdir("//---Path to working directory---//")
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# WindowsError                              Traceback (most recent call last)
# <ipython-input-1-bbabbbc410da> in <module>()
#      10
#      11 # Set working directory
# ---> 12 os.chdir("//---Path to working directory---//")
#      13 print(os.getcwd())
#
# WindowsError: [Error 161] The specified path is invalid: '//---Path to working directory---//'

# %%
# Define a function to scrape doctor search results
def scrape_doctors():
    # Number of pages of results available
    noOfPages = driver.find_element_by_xpath('/html/body/form/section/div/div/div[3]/div[1]/div[1]/div[2]/p')
    noOfPages = noOfPages.text
    print(noOfPages)
    noOfPages = noOfPages.split(' ')
    noOfPages = int(noOfPages[3])
    print("Number of pages: {}".format(noOfPages))
    
    # Create a df to hold all results for the selected city
    resultsDf = pd.DataFrame(columns=['Name', 'ID', 'Location', 'Details'])
    print(resultsDf)

    for i in range(1,noOfPages+1):
        # Getting the current page from the webpage
        currentPage = driver.find_element_by_xpath('/html/body/form/section/div/div/div[3]/div[1]/div[1]/div[2]/p')
        currentPage = currentPage.text
        currentPage = currentPage.split(" ")
        currentPage = int(currentPage[1])

        # Getting a list of all the results in the current page
        listOfArticles = driver.find_elements_by_tag_name('article')

        print("Iteration number: {}".format(i))
        print("Number of results in page %s is: %s" %(currentPage, len(listOfArticles)))

        for article in listOfArticles:
            name = article.find_element_by_xpath('.//h3/a').text
            idno = article.find_element_by_xpath('.//h3').text
            location = article.find_element_by_xpath('.//p').text
            try:
                details = article.find_element_by_xpath('.//div/p').text
            except NoSuchElementException:  # The specialisations and other notes are unavailable for certain results
                details = np.nan
                pass

            resultsDf = resultsDf.append([{'Name':name, 'ID':idno, 'Location':location, 'Details':details}],
                                               ignore_index=True) 
            # ignore_index sets the index to continuos number instead of 0 for each row

        # Print the shape of dataframe in each iteration 
        print("The size of dataframe at the end of iteration {} is {}".format(i,resultsDf.shape))

        if(i==noOfPages):
            break

        if(i%5==1):
            nextPageButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl03_CPSO_DoctorSearchResults_rptPages_ctl01_lnbPage')

        if(i%5==2):
            nextPageButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl03_CPSO_DoctorSearchResults_rptPages_ctl02_lnbPage')

        if(i%5==3):
            nextPageButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl03_CPSO_DoctorSearchResults_rptPages_ctl03_lnbPage')

        if(i%5==4):
            nextPageButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl03_CPSO_DoctorSearchResults_rptPages_ctl04_lnbPage')

        if(i%5==0):
            nextPageButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl03_CPSO_DoctorSearchResults_lnbNextGroup')

        nextPageButton.click()
        # Introducing a wait time for the page to load
        time.sleep(2)

        # End of for loop to iterate over each page
    print('The total number of results scraped: {}'.format(resultsDf.shape))  
    
    return resultsDf
# End of function

# %%
## Open a chrome session using Selenium chrome web driver
DRIVER_PATH = '---Path to chromedriver---'
driver = webdriver.Chrome()

# %%
## Scrape family physicians in Kitchener
# Opening the URL for CPSO doctor search
link = "https://doctors.cpso.on.ca/?search=general"
driver.get(link)

# Select the dropdown button for choosing the city
cityDropdown = Select(driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_ddCity'))
# 1. Select the city of Kitchener from the dropdown
cityDropdown.select_by_value('1515') #Pass value as string

# Select family physicians only
familyDoc = driver.find_element_by_xpath('/html/body/form/section/div/div/div[2]/div/div/div/div[1]/div/div[3]/div[3]/div[2]/div/section[1]/fieldset/div[1]/label[1]')
familyDoc.click()

# Click the submit button
submitButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_btnSubmit1')
submitButton.click()

# Introducing a wait time for the page to load
time.sleep(7)

kitchenerDoctors = scrape_doctors()

# # Write the results in a csv file
# kitchenerDoctors.to_csv('Results_Kitchener.csv', header=True)
# Out:
# Page 1 of 35
# Number of pages: 35
# Empty DataFrame
# Columns: [Name, ID, Location, Details]
# Index: []
# Iteration number: 1
# Number of results in page 1 is: 10
# The size of dataframe at the end of iteration 1 is (10, 4)
# Iteration number: 2
# Number of results in page 2 is: 10
# The size of dataframe at the end of iteration 2 is (20, 4)
# Iteration number: 3
# Number of results in page 3 is: 10
# The size of dataframe at the end of iteration 3 is (30, 4)
# Iteration number: 4
# Number of results in page 4 is: 10
# The size of dataframe at the end of iteration 4 is (40, 4)
# Iteration number: 5
# Number of results in page 5 is: 10
# The size of dataframe at the end of iteration 5 is (50, 4)
# Iteration number: 6
# Number of results in page 6 is: 10
# The size of dataframe at the end of iteration 6 is (60, 4)
# Iteration number: 7
# Number of results in page 7 is: 10
# The size of dataframe at the end of iteration 7 is (70, 4)
# Iteration number: 8
# Number of results in page 8 is: 10
# The size of dataframe at the end of iteration 8 is (80, 4)
# Iteration number: 9
# Number of results in page 9 is: 10
# The size of dataframe at the end of iteration 9 is (90, 4)
# Iteration number: 10
# Number of results in page 10 is: 10
# The size of dataframe at the end of iteration 10 is (100, 4)
# Iteration number: 11
# Number of results in page 11 is: 10
# The size of dataframe at the end of iteration 11 is (110, 4)
# Iteration number: 12
# Number of results in page 12 is: 10
# The size of dataframe at the end of iteration 12 is (120, 4)
# Iteration number: 13
# Number of results in page 13 is: 10
# The size of dataframe at the end of iteration 13 is (130, 4)
# Iteration number: 14
# Number of results in page 14 is: 10
# The size of dataframe at the end of iteration 14 is (140, 4)
# Iteration number: 15
# Number of results in page 15 is: 10
# The size of dataframe at the end of iteration 15 is (150, 4)
# Iteration number: 16
# Number of results in page 16 is: 10
# The size of dataframe at the end of iteration 16 is (160, 4)
# Iteration number: 17
# Number of results in page 17 is: 10
# The size of dataframe at the end of iteration 17 is (170, 4)
# Iteration number: 18
# Number of results in page 18 is: 10
# The size of dataframe at the end of iteration 18 is (180, 4)
# Iteration number: 19
# Number of results in page 19 is: 10
# The size of dataframe at the end of iteration 19 is (190, 4)
# Iteration number: 20
# Number of results in page 20 is: 10
# The size of dataframe at the end of iteration 20 is (200, 4)
# Iteration number: 21
# Number of results in page 21 is: 10
# The size of dataframe at the end of iteration 21 is (210, 4)
# Iteration number: 22
# Number of results in page 22 is: 10
# The size of dataframe at the end of iteration 22 is (220, 4)
# Iteration number: 23
# Number of results in page 23 is: 10
# The size of dataframe at the end of iteration 23 is (230, 4)
# Iteration number: 24
# Number of results in page 24 is: 10
# The size of dataframe at the end of iteration 24 is (240, 4)
# Iteration number: 25
# Number of results in page 25 is: 10
# The size of dataframe at the end of iteration 25 is (250, 4)
# Iteration number: 26
# Number of results in page 26 is: 10
# The size of dataframe at the end of iteration 26 is (260, 4)
# Iteration number: 27
# Number of results in page 27 is: 10
# The size of dataframe at the end of iteration 27 is (270, 4)
# Iteration number: 28
# Number of results in page 28 is: 10
# The size of dataframe at the end of iteration 28 is (280, 4)
# Iteration number: 29
# Number of results in page 29 is: 10
# The size of dataframe at the end of iteration 29 is (290, 4)
# Iteration number: 30
# Number of results in page 30 is: 10
# The size of dataframe at the end of iteration 30 is (300, 4)
# Iteration number: 31
# Number of results in page 31 is: 10
# The size of dataframe at the end of iteration 31 is (310, 4)
# Iteration number: 32
# Number of results in page 32 is: 10
# The size of dataframe at the end of iteration 32 is (320, 4)
# Iteration number: 33
# Number of results in page 33 is: 10
# The size of dataframe at the end of iteration 33 is (330, 4)
# Iteration number: 34
# Number of results in page 34 is: 10
# The size of dataframe at the end of iteration 34 is (340, 4)
# Iteration number: 35
# Number of results in page 35 is: 2
# The size of dataframe at the end of iteration 35 is (342, 4)
# The total number of results scraped: (342, 4)

# %%
## Scrape family physicians in Waterloo
# Opening the URL for CPSO doctor search
link = "https://doctors.cpso.on.ca/?search=general"
driver.get(link)

# Select the dropdown button for choosing the city
cityDropdown = Select(driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_ddCity'))
# 2. Select the city of Waterloo from the dropdown
cityDropdown.select_by_value('2017') #Pass value as string

# Select family physicians only
familyDoc = driver.find_element_by_xpath('/html/body/form/section/div/div/div[2]/div/div/div/div[1]/div/div[3]/div[3]/div[2]/div/section[1]/fieldset/div[1]/label[1]')
familyDoc.click()

# Click the submit button
submitButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_btnSubmit1')
submitButton.click()

# Introducing a wait time for the page to load
time.sleep(7)

waterlooDoctors = scrape_doctors()

# # Write the results in a csv file
# waterlooDoctors.to_csv('Results_Waterloo.csv', header=True)
# Out:
# Page 1 of 17
# Number of pages: 17
# Empty DataFrame
# Columns: [Name, ID, Location, Details]
# Index: []
# Iteration number: 1
# Number of results in page 1 is: 10
# The size of dataframe at the end of iteration 1 is (10, 4)
# Iteration number: 2
# Number of results in page 2 is: 10
# The size of dataframe at the end of iteration 2 is (20, 4)
# Iteration number: 3
# Number of results in page 3 is: 10
# The size of dataframe at the end of iteration 3 is (30, 4)
# Iteration number: 4
# Number of results in page 4 is: 10
# The size of dataframe at the end of iteration 4 is (40, 4)
# Iteration number: 5
# Number of results in page 5 is: 10
# The size of dataframe at the end of iteration 5 is (50, 4)
# Iteration number: 6
# Number of results in page 6 is: 10
# The size of dataframe at the end of iteration 6 is (60, 4)
# Iteration number: 7
# Number of results in page 7 is: 10
# The size of dataframe at the end of iteration 7 is (70, 4)
# Iteration number: 8
# Number of results in page 8 is: 10
# The size of dataframe at the end of iteration 8 is (80, 4)
# Iteration number: 9
# Number of results in page 9 is: 10
# The size of dataframe at the end of iteration 9 is (90, 4)
# Iteration number: 10
# Number of results in page 10 is: 10
# The size of dataframe at the end of iteration 10 is (100, 4)
# Iteration number: 11
# Number of results in page 11 is: 10
# The size of dataframe at the end of iteration 11 is (110, 4)
# Iteration number: 12
# Number of results in page 12 is: 10
# The size of dataframe at the end of iteration 12 is (120, 4)
# Iteration number: 13
# Number of results in page 13 is: 10
# The size of dataframe at the end of iteration 13 is (130, 4)
# Iteration number: 14
# Number of results in page 14 is: 10
# The size of dataframe at the end of iteration 14 is (140, 4)
# Iteration number: 15
# Number of results in page 15 is: 10
# The size of dataframe at the end of iteration 15 is (150, 4)
# Iteration number: 16
# Number of results in page 16 is: 10
# The size of dataframe at the end of iteration 16 is (160, 4)
# Iteration number: 17
# Number of results in page 17 is: 7
# The size of dataframe at the end of iteration 17 is (167, 4)
# The total number of results scraped: (167, 4)

# %%
## Scrape family physicians in Cambridge
# Opening the URL for CPSO doctor search
link = "https://doctors.cpso.on.ca/?search=general"
driver.get(link)

# Select the dropdown button for choosing the city
cityDropdown = Select(driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_ddCity'))
# 3. Select Cambridge from the dropdown
cityDropdown.select_by_value('1164') #Pass value as string

# Select family physicians only
familyDoc = driver.find_element_by_xpath('/html/body/form/section/div/div/div[2]/div/div/div/div[1]/div/div[3]/div[3]/div[2]/div/section[1]/fieldset/div[1]/label[1]')
familyDoc.click()

# Click the submit button
submitButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_btnSubmit1')
submitButton.click()

# Introducing a wait time for the page to load
time.sleep(7)

cambridgeDoctors = scrape_doctors()

# # Write the results in a csv file
# cambridgeDoctors.to_csv('Results_Cambridge.csv', header=True)
# Out:
# Page 1 of 18
# Number of pages: 18
# Empty DataFrame
# Columns: [Name, ID, Location, Details]
# Index: []
# Iteration number: 1
# Number of results in page 1 is: 10
# The size of dataframe at the end of iteration 1 is (10, 4)
# Iteration number: 2
# Number of results in page 2 is: 10
# The size of dataframe at the end of iteration 2 is (20, 4)
# Iteration number: 3
# Number of results in page 3 is: 10
# The size of dataframe at the end of iteration 3 is (30, 4)
# Iteration number: 4
# Number of results in page 4 is: 10
# The size of dataframe at the end of iteration 4 is (40, 4)
# Iteration number: 5
# Number of results in page 5 is: 10
# The size of dataframe at the end of iteration 5 is (50, 4)
# Iteration number: 6
# Number of results in page 6 is: 10
# The size of dataframe at the end of iteration 6 is (60, 4)
# Iteration number: 7
# Number of results in page 7 is: 10
# The size of dataframe at the end of iteration 7 is (70, 4)
# Iteration number: 8
# Number of results in page 8 is: 10
# The size of dataframe at the end of iteration 8 is (80, 4)
# Iteration number: 9
# Number of results in page 9 is: 10
# The size of dataframe at the end of iteration 9 is (90, 4)
# Iteration number: 10
# Number of results in page 10 is: 10
# The size of dataframe at the end of iteration 10 is (100, 4)
# Iteration number: 11
# Number of results in page 11 is: 10
# The size of dataframe at the end of iteration 11 is (110, 4)
# Iteration number: 12
# Number of results in page 12 is: 10
# The size of dataframe at the end of iteration 12 is (120, 4)
# Iteration number: 13
# Number of results in page 13 is: 10
# The size of dataframe at the end of iteration 13 is (130, 4)
# Iteration number: 14
# Number of results in page 14 is: 10
# The size of dataframe at the end of iteration 14 is (140, 4)
# Iteration number: 15
# Number of results in page 15 is: 10
# The size of dataframe at the end of iteration 15 is (150, 4)
# Iteration number: 16
# Number of results in page 16 is: 10
# The size of dataframe at the end of iteration 16 is (160, 4)
# Iteration number: 17
# Number of results in page 17 is: 10
# The size of dataframe at the end of iteration 17 is (170, 4)
# Iteration number: 18
# Number of results in page 18 is: 8
# The size of dataframe at the end of iteration 18 is (178, 4)
# The total number of results scraped: (178, 4)

# %%
## Scrape family physicians in Guelph
# Opening the URL for CPSO doctor search
link = "https://doctors.cpso.on.ca/?search=general"
driver.get(link)

# Select the dropdown button for choosing the city
cityDropdown = Select(driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_ddCity'))
# 4. Select Guelph from the dropdown
cityDropdown.select_by_value('1417') #Pass value as string

# Select family physicians only
familyDoc = driver.find_element_by_xpath('/html/body/form/section/div/div/div[2]/div/div/div/div[1]/div/div[3]/div[3]/div[2]/div/section[1]/fieldset/div[1]/label[1]')
familyDoc.click()

# Click the submit button
submitButton = driver.find_element_by_id('p_lt_ctl01_pageplaceholder_p_lt_ctl02_CPSO_AllDoctorsSearch_btnSubmit1')
submitButton.click()

# Introducing a wait time for the page to load
time.sleep(7)

guelphDoctors = scrape_doctors()

# # Write the results in a csv file
# guelphDoctors.to_csv('Results_Guelph.csv', header=True)
# Out:
# Page 1 of 23
# Number of pages: 23
# Empty DataFrame
# Columns: [Name, ID, Location, Details]
# Index: []
# Iteration number: 1
# Number of results in page 1 is: 10
# The size of dataframe at the end of iteration 1 is (10, 4)
# Iteration number: 2
# Number of results in page 2 is: 10
# The size of dataframe at the end of iteration 2 is (20, 4)
# Iteration number: 3
# Number of results in page 3 is: 10
# The size of dataframe at the end of iteration 3 is (30, 4)
# Iteration number: 4
# Number of results in page 4 is: 10
# The size of dataframe at the end of iteration 4 is (40, 4)
# Iteration number: 5
# Number of results in page 5 is: 10
# The size of dataframe at the end of iteration 5 is (50, 4)
# Iteration number: 6
# Number of results in page 6 is: 10
# The size of dataframe at the end of iteration 6 is (60, 4)
# Iteration number: 7
# Number of results in page 7 is: 10
# The size of dataframe at the end of iteration 7 is (70, 4)
# Iteration number: 8
# Number of results in page 8 is: 10
# The size of dataframe at the end of iteration 8 is (80, 4)
# Iteration number: 9
# Number of results in page 9 is: 10
# The size of dataframe at the end of iteration 9 is (90, 4)
# Iteration number: 10
# Number of results in page 10 is: 10
# The size of dataframe at the end of iteration 10 is (100, 4)
# Iteration number: 11
# Number of results in page 11 is: 10
# The size of dataframe at the end of iteration 11 is (110, 4)
# Iteration number: 12
# Number of results in page 12 is: 10
# The size of dataframe at the end of iteration 12 is (120, 4)
# Iteration number: 13
# Number of results in page 13 is: 10
# The size of dataframe at the end of iteration 13 is (130, 4)
# Iteration number: 14
# Number of results in page 14 is: 10
# The size of dataframe at the end of iteration 14 is (140, 4)
# Iteration number: 15
# Number of results in page 15 is: 10
# The size of dataframe at the end of iteration 15 is (150, 4)
# Iteration number: 16
# Number of results in page 16 is: 10
# The size of dataframe at the end of iteration 16 is (160, 4)
# Iteration number: 17
# Number of results in page 17 is: 10
# The size of dataframe at the end of iteration 17 is (170, 4)
# Iteration number: 18
# Number of results in page 18 is: 10
# The size of dataframe at the end of iteration 18 is (180, 4)
# Iteration number: 19
# Number of results in page 19 is: 10
# The size of dataframe at the end of iteration 19 is (190, 4)
# Iteration number: 20
# Number of results in page 20 is: 10
# The size of dataframe at the end of iteration 20 is (200, 4)
# Iteration number: 21
# Number of results in page 21 is: 10
# The size of dataframe at the end of iteration 21 is (210, 4)
# Iteration number: 22
# Number of results in page 22 is: 10
# The size of dataframe at the end of iteration 22 is (220, 4)
# Iteration number: 23
# Number of results in page 23 is: 3
# The size of dataframe at the end of iteration 23 is (223, 4)
# The total number of results scraped: (223, 4)

# %%
kitchenerDoctors['City'] = 'Kitchener'
waterlooDoctors['City'] = 'Waterloo'
cambridgeDoctors['City'] = 'Cambridge'
guelphDoctors['City'] = 'Guelph'
## Combining all the results dataframes to clean and structure the data
allDocsDf = kitchenerDoctors
allDocsDf = allDocsDf.append([waterlooDoctors,cambridgeDoctors,guelphDoctors],
                             ignore_index = True)
print(allDocsDf.shape)
print(allDocsDf.head(10))
# Out:
# (910, 5)
#                              Name  \
# 0                Abbasi, Iram Naz
# 1               Abdelmalak, Peter
# 2                     Adel, Shiva
# 3               Agbenyega, Akuafo
# 4              Alarakhia, Mohamed
# 5       Al-Attar, Salam Akram Ali
# 6          Al-Halimi, Maha Khalil
# 7  Al-Zubaidy, Layla Makky Nassir
# 8            Amdemichael, Esiahas
# 9      Andersen, Laura Leigh Lise
#
#                                                ID  \
# 0                 Abbasi, Iram Naz (CPSO#: 89840)
# 1               Abdelmalak, Peter (CPSO#: 112142)
# 2                     Adel, Shiva (CPSO#: 106240)
# 3               Agbenyega, Akuafo (CPSO#: 120499)
# 4               Alarakhia, Mohamed (CPSO#: 88754)
# 5        Al-Attar, Salam Akram Ali (CPSO#: 97865)
# 6           Al-Halimi, Maha Khalil (CPSO#: 99645)
# 7  Al-Zubaidy, Layla Makky Nassir (CPSO#: 127810)
# 8             Amdemichael, Esiahas (CPSO#: 62458)
# 9       Andersen, Laura Leigh Lise (CPSO#: 98890)
#
#                                             Location  \
# 0  Suite 201\n1450 Block Line Road\nKitchener ON ...
# 1  167 Hespeler Rd\nGrandview Medical Centre\nCam...
# 2  Unit 203\n310 King Street East\nKitchener ON  ...
# 3  Grand River Hospital\n835 King St W\nKitchener...
# 4  Suite 4111\n250 Laurelwood Drive\nWaterloo ON ...
# 5  75 Montpelier St\nIntrepid Medical Centre\nBra...
# 6  450 Westheight drive\nUnit 11\nKitchener ON  N...
# 7              A-51 Benton St\nKitchener ON  N2G 3H1
# 8  Suite 26\n385 Frederick Street\nKitchener ON  ...
# 9  16 ANDREW STREET\nKitchener ON  N2H 5R2\nPhone...
#
#                                              Details       City
# 0                                    Family Medicine  Kitchener
# 1  This doctor has additional practice locations ...  Kitchener
# 2                                    Family Medicine  Kitchener
# 3  This doctor has additional practice locations ...  Kitchener
# 4  This doctor has additional practice locations ...  Kitchener
# 5  This doctor has additional practice locations ...  Kitchener
# 6  This doctor has additional practice locations ...  Kitchener
# 7                                    Family Medicine  Kitchener
# 8  This doctor has additional practice locations ...  Kitchener
# 9                                    Family Medicine  Kitchener

# %%
allDocsDf[['LastName','FirstName']] = allDocsDf['Name'].str.split(',', expand = True)
allDocsDf['CPSOID'] = allDocsDf['ID'].str.extract('([0-9]+)',expand=False)
allDocsDf['Location'] = allDocsDf['Location'].replace({"\\n":" "}, regex=True)
# extract phone and fax numbers
allDocsDf[['Location','Phone']] = allDocsDf['Location'].str.split("Phone:",expand=True)
allDocsDf[['Phone','Fax']] = allDocsDf['Phone'].str.split("Fax:",expand=True)
# extract postal codes from the address
allDocsDf['Postal Code'] = allDocsDf['Location'].str.extract('([A-Z]\d[A-Z]\s?\d[A-Z]\d)', expand=False)
# Extract the additional practice locations to a new column
allDocsDf[['Details','Additional Locations']] = allDocsDf['Details'].str.split("This doctor has additional practice locations in:", expand=True)
allDocsDf[['Details','Former Name']] = allDocsDf['Details'].str.split("Former Name:", expand=True)
# Rename and delete columns
allDocsDf = allDocsDf.rename(columns={"Details":"Specializations"})
allDocsDf = allDocsDf.drop("ID", axis=1)

print(allDocsDf.shape)

# Merge the doctors per location count column
locationTable = pd.DataFrame(allDocsDf['Location'].value_counts().reset_index())
locationTable.columns = ['Location','LocationCount']
allDocsDf = pd.merge(allDocsDf,locationTable, on='Location')
allDocsDf['LocationFlag'] = np.where(allDocsDf['LocationCount']>1,"Multiple doctors", "Single practitioner location")
allDocsDf = allDocsDf.drop("LocationCount", axis=1)

# Getting ohone numbers of practice locations with maximum doctors
print(allDocsDf['Phone'].value_counts())
print(allDocsDf.shape)
print(allDocsDf.head(20))

# Write the results in a csv file
allDocsDf.to_csv('Results_family doctors KWCG.csv', header=True)
# Out:
# (910, 12)
#                               Name  \
# 0                 Abbasi, Iram Naz
# 1                Abdelmalak, Peter
# 2                      Adel, Shiva
# 3                Agbenyega, Akuafo
# 4               Alarakhia, Mohamed
# 5        Al-Attar, Salam Akram Ali
# 6           Al-Halimi, Maha Khalil
# 7   Al-Zubaidy, Layla Makky Nassir
# 8             Amdemichael, Esiahas
# 9       Andersen, Laura Leigh Lise
# 10              Arora, Serena Jain
# 11              Arya, Akshaya Neil
# 12                     Asif, Anjum
# 13          Atia, Rafaa Sobhi Zaki
# 14             Azi, Adaku Michelle
# 15            Bajwa, Sukhjiv Singh
# 16               Bauman, Kent Evan
# 17              Bausmer, Tracy Ann
# 18        Bednarska, Elzbieta Inez
# 19               Bell, Brian David
#
#                                              Location  Specializations  \
# 0   Suite 201 1450 Block Line Road Kitchener ON  N...  Family Medicine
# 1   167 Hespeler Rd Grandview Medical Centre Cambr...
# 2   Unit 203 310 King Street East Kitchener ON  N2...  Family Medicine
# 3   Grand River Hospital 835 King St W Kitchener O...
# 4   Suite 4111 250 Laurelwood Drive Waterloo ON  N...
# 5   75 Montpelier St Intrepid Medical Centre Bramp...
# 6   450 Westheight drive Unit 11 Kitchener ON  N2N...
# 7                A-51 Benton St Kitchener ON  N2G 3H1  Family Medicine
# 8   Suite 26 385 Frederick Street Kitchener ON  N2...
# 9             16 ANDREW STREET Kitchener ON  N2H 5R2   Family Medicine
# 10  1-1280 Main St W McMaster University Student W...
# 11  Centre for Family Medicine 10B Victoria Street...  Family Medicine
# 12      Unit 103 611 Holly Avenue Milton ON  L9T 0K4
# 13  Suite 201 751 Victoria Street South Kitchener ...  Family Medicine
# 14  2200-222 King Street East Bowmanville ON  L1C1P6
# 15  Grand River Hospital 835 King St W Kitchener O...
# 16  Beechwood Forest Medical Centre Suite 2 890 Gl...  Family Medicine
# 17                       Former Name: Chin, Tracy Ann
# 18  Andrew Street Family Health Centre 16 Andrew S...  Family Medicine
# 19  St Mary's Hospital 911 Queen's Boulevard Kitch...
#
#          City     LastName            FirstName  CPSOID  \
# 0   Kitchener       Abbasi             Iram Naz   89840
# 1   Kitchener   Abdelmalak                Peter  112142
# 2   Kitchener         Adel                Shiva  106240
# 3   Kitchener    Agbenyega               Akuafo  120499
# 4   Kitchener    Alarakhia              Mohamed   88754
# 5   Kitchener     Al-Attar      Salam Akram Ali   97865
# 6   Kitchener    Al-Halimi          Maha Khalil   99645
# 7   Kitchener   Al-Zubaidy   Layla Makky Nassir  127810
# 8   Kitchener  Amdemichael              Esiahas   62458
# 9   Kitchener     Andersen     Laura Leigh Lise   98890
# 10  Kitchener        Arora          Serena Jain  118311
# 11  Kitchener         Arya         Akshaya Neil   64831
# 12  Kitchener         Asif                Anjum   91547
# 13  Kitchener         Atia     Rafaa Sobhi Zaki   81808
# 14  Kitchener          Azi       Adaku Michelle   85300
# 15  Kitchener        Bajwa        Sukhjiv Singh  105056
# 16  Kitchener       Bauman            Kent Evan   58236
# 17  Kitchener      Bausmer            Tracy Ann   77916
# 18  Kitchener    Bednarska        Elzbieta Inez   90573
# 19  Kitchener         Bell          Brian David   70755
#
#                        Phone              Fax Postal Code  \
# 0             (519)578-4450      519-579-1142     N2C 0A5
# 1             (519) 623-4200             None     N1R 3H7
# 2             (226) 336-1321             None     N2G 2L3
# 3             (519) 749-4300             None     N2G 1G3
# 4            (519) 904-0656    (519) 904-0658      N2J0E2
# 5               289-401-4678             None     L6Y 6H4
# 6              519-725-4070      226-215-3333      N2N2B9
# 7                       None             None     N2G 3H1
# 8            (519) 578-1332    (519) 578-1399     N2H 2P2
# 9              519-804-9234      519-804-2604     N2H 5R2
# 10   905-525-9140 Ext. 27700             None     L8S 4K1
# 11           (519) 783-0021    (519) 783-0031     N2G 1C5
# 12           (905) 878-0086    (905) 878-1562     L9T 0K4
# 13           (519) 571-8744    (519) 571-3253     N2M 5N4
# 14        9054403600 Ext. 1        9056977745      L1C1P6
# 15              519-749-4300             None     N2G 1G3
# 16           (519) 744-4293    (519) 744-6424     N2N 3G6
# 17                      None             None         NaN
# 18           (519) 804-9234    (519) 804-2604     N2H 5R2
# 19            (519) 744-3311             None     N2M 1B2
#
#                  Additional Locations       Former Name
# 0                                None              None
# 1                           Kitchener              None
# 2                                None              None
# 3                           Kitchener              None
# 4                           Kitchener              None
# 5    Brampton, Kitchener, Mississauga              None
# 6                            Waterloo              None
# 7                                None              None
# 8                            Brampton              None
# 9                                None              None
# 10                          Kitchener              None
# 11                               None              None
# 12                          Kitchener              None
# 13                               None              None
# 14                  Kitchener, Oshawa              None
# 15                Hamilton, Kitchener              None
# 16                               None              None
# 17                               None   Chin, Tracy Ann
# 18                               None              None
# 19                          Kitchener              None
#  (519) 749-4300                21
#  (519) 621-2330                19
#  (519) 822-5350                16
#  (519) 578-3510                16
#  (519) 766-1360                14
#  (519) 742-3611                13
#  (519) 629-4615                12
#  (519) 623-4200                12
#  (519) 747-1200                 8
#  (519) 804-9234                 8
#  519-745-7482                   7
#  (519) 837-2283                 6
#  226-476-3178                   6
#  (519) 744-2592                 6
#  (519) 725-1514                 5
#  (519) 783-0022                 5
#  (519) 749-6410                 5
#  (519) 747-2172                 5
#  (519) 744-3311                 5
#  519-571-8181                   5
#  519-749-4300                   5
#  (519) 749-4242                 4
#  (519) 576-2992                 4
#  (519) 569-8821                 4
#  (519) 742-0107                 4
#  (519) 748-6933                 4
#  519-725-1514                   4
#  (519) 904-0656                 4
#  519-804-9234                   4
#  (519) 783-0021                 4
#                                ..
#  (519) 621-2333 Ext. 2200       1
#  519-442-9999                   1
#  (519) 829-1414                 1
#  (519) 741-5724                 1
#  (519) 745-3117                 1
#  (519) 578-3500                 1
#  (905) 527-0271 Ext. 46277      1
#  519 360 9000                   1
#  226-499-6991                   1
#  5195783510                     1
#  519-824-1010                   1
#  (416) 242-1000                 1
#  5192656004                     1
#  (519) 822-6700                 1
#  519-822-7841                   1
#  (519) 571-9893                 1
#  519-740-1700                   1
#  519 837 1401                   1
#  (519) 501-4293                 1
#  519-893-6200                   1
#  (519) 749-4380                 1
#  (519) 843-2010                 1
#  (519) 749-4300 Ext. 4242       1
#  519-749-4300 Ext. 2242         1
#  (416) 703-8480                 1
#  (519) 579-8181                 1
#  9057643300                     1
#  (519) 743-2951                 1
#  (519) 829-3838                 1
#  (519) 896-6699                 1
# Name: Phone, Length: 500, dtype: int64
# (910, 13)
#                                     Name  \
# 0                       Abbasi, Iram Naz
# 1                      Abdelmalak, Peter
# 2                      Abdelmalak, Peter
# 3                            Adel, Shiva
# 4                      Agbenyega, Akuafo
# 5                   Bajwa, Sukhjiv Singh
# 6                Dowhos, Krista Michelle
# 7                Kowtecky, Philip Andrew
# 8   Lenferna De La Motte, Pierre Georges
# 9              Ritcey, David Brien James
# 10                       Truong, Jenifer
# 11                 Yantzi, Allison Marie
# 12                       Truong, Jenifer
# 13                    Alarakhia, Mohamed
# 14                    Alarakhia, Mohamed
# 15             Al-Attar, Salam Akram Ali
# 16                Al-Halimi, Maha Khalil
# 17                Al-Halimi, Maha Khalil
# 18        Al-Zubaidy, Layla Makky Nassir
# 19                  Amdemichael, Esiahas
#
#                                              Location  Specializations  \
# 0   Suite 201 1450 Block Line Road Kitchener ON  N...  Family Medicine
# 1   167 Hespeler Rd Grandview Medical Centre Cambr...
# 2   167 Hespeler Rd Grandview Medical Centre Cambr...
# 3   Unit 203 310 King Street East Kitchener ON  N2...  Family Medicine
# 4   Grand River Hospital 835 King St W Kitchener O...
# 5   Grand River Hospital 835 King St W Kitchener O...
# 6   Grand River Hospital 835 King St W Kitchener O...  Family Medicine
# 7   Grand River Hospital 835 King St W Kitchener O...  Family Medicine
# 8   Grand River Hospital 835 King St W Kitchener O...
# 9   Grand River Hospital 835 King St W Kitchener O...  Family Medicine
# 10  Grand River Hospital 835 King St W Kitchener O...
# 11  Grand River Hospital 835 King St W Kitchener O...
# 12  Grand River Hospital 835 King St W Kitchener O...
# 13  Suite 4111 250 Laurelwood Drive Waterloo ON  N...
# 14  Suite 4111 250 Laurelwood Drive Waterloo ON  N...
# 15  75 Montpelier St Intrepid Medical Centre Bramp...
# 16  450 Westheight drive Unit 11 Kitchener ON  N2N...
# 17  450 Westheight drive Unit 11 Kitchener ON  N2N...
# 18               A-51 Benton St Kitchener ON  N2G 3H1  Family Medicine
# 19  Suite 26 385 Frederick Street Kitchener ON  N2...
#
#          City              LastName            FirstName  CPSOID  \
# 0   Kitchener                Abbasi             Iram Naz   89840
# 1   Kitchener            Abdelmalak                Peter  112142
# 2   Cambridge            Abdelmalak                Peter  112142
# 3   Kitchener                  Adel                Shiva  106240
# 4   Kitchener             Agbenyega               Akuafo  120499
# 5   Kitchener                 Bajwa        Sukhjiv Singh  105056
# 6   Kitchener                Dowhos      Krista Michelle  115470
# 7   Kitchener              Kowtecky        Philip Andrew   93697
# 8   Kitchener  Lenferna De La Motte       Pierre Georges  105806
# 9   Kitchener                Ritcey    David Brien James  109397
# 10  Kitchener                Truong              Jenifer  112221
# 11  Kitchener                Yantzi        Allison Marie  106497
# 12     Guelph                Truong              Jenifer  112221
# 13  Kitchener             Alarakhia              Mohamed   88754
# 14   Waterloo             Alarakhia              Mohamed   88754
# 15  Kitchener              Al-Attar      Salam Akram Ali   97865
# 16  Kitchener             Al-Halimi          Maha Khalil   99645
# 17   Waterloo             Al-Halimi          Maha Khalil   99645
# 18  Kitchener            Al-Zubaidy   Layla Makky Nassir  127810
# 19  Kitchener           Amdemichael              Esiahas   62458
#
#                Phone              Fax Postal Code  \
# 0     (519)578-4450      519-579-1142     N2C 0A5
# 1     (519) 623-4200             None     N1R 3H7
# 2     (519) 623-4200             None     N1R 3H7
# 3     (226) 336-1321             None     N2G 2L3
# 4     (519) 749-4300             None     N2G 1G3
# 5       519-749-4300             None     N2G 1G3
# 6     (519) 749-4300             None     N2G 1G3
# 7     (519) 749-4300             None     N2G 1G3
# 8     (519) 742-3611             None     N2G 1G3
# 9     (519) 749-4300             None     N2G 1G3
# 10    (519) 749-4300             None     N2G 1G3
# 11      519-749-4300             None     N2G 1G3
# 12    (519) 749-4300             None     N2G 1G3
# 13   (519) 904-0656    (519) 904-0658      N2J0E2
# 14   (519) 904-0656    (519) 904-0658      N2J0E2
# 15      289-401-4678             None     L6Y 6H4
# 16     519-725-4070      226-215-3333      N2N2B9
# 17     519-725-4070      226-215-3333      N2N2B9
# 18              None             None     N2G 3H1
# 19   (519) 578-1332    (519) 578-1399     N2H 2P2
#
#                  Additional Locations Former Name  \
# 0                                None        None
# 1                           Kitchener        None
# 2                           Kitchener        None
# 3                                None        None
# 4                           Kitchener        None
# 5                 Hamilton, Kitchener        None
# 6                                None        None
# 7                                None        None
# 8                           Kitchener        None
# 9                                None        None
# 10                  Guelph, Kitchener        None
# 11                          Kitchener        None
# 12                  Guelph, Kitchener        None
# 13                          Kitchener        None
# 14                          Kitchener        None
# 15   Brampton, Kitchener, Mississauga        None
# 16                           Waterloo        None
# 17                           Waterloo        None
# 18                               None        None
# 19                           Brampton        None
#
#                     LocationFlag
# 0   Single practitioner location
# 1               Multiple doctors
# 2               Multiple doctors
# 3   Single practitioner location
# 4               Multiple doctors
# 5               Multiple doctors
# 6               Multiple doctors
# 7               Multiple doctors
# 8               Multiple doctors
# 9               Multiple doctors
# 10              Multiple doctors
# 11              Multiple doctors
# 12              Multiple doctors
# 13              Multiple doctors
# 14              Multiple doctors
# 15  Single practitioner location
# 16              Multiple doctors
# 17              Multiple doctors
# 18  Single practitioner location
# 19              Multiple doctors
